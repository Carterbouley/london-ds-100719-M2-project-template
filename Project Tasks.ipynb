# %%
# %load_ext autoreloa

# %%
# %autoreload

# %%
import requests

# %%
from lib import MongoHandler, WeatherGetter
import json
import pandas as pd

# %%
WeatherGetter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-7ebbb608ae13> in <module>
# ----> 1 WeatherGetter(42.3601)
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
forecast = requests.get('https://api.darksky.net/forecast/24403211014f1a2bafda648dd797c7ff/42.3601,71.0589')

# %%
forecast
# Out:
# <Response [200]>

# %%
print(forecast)
# Out:
# <Response [200]>

# %%
GET forecast
# Out:
#   File "<ipython-input-32-dd67c1fb5c1b>", line 1
#     GET forecast
#                ^
# SyntaxError: invalid syntax

# %%
forecast.json()
# Out:
# {'latitude': 42.3601,
#  'longitude': 71.0589,
#  'timezone': 'Asia/Almaty',
#  'currently': {'time': 1572510394,
#   'summary': 'Overcast',
#   'icon': 'cloudy',
#   'precipIntensity': 0.0105,
#   'precipProbability': 0.07,
#   'precipType': 'rain',
#   'temperature': 42.52,
#   'apparentTemperature': 38.92,
#   'dewPoint': 29.51,
#   'humidity': 0.6,
#   'pressure': 1016.1,
#   'windSpeed': 5.76,
#   'windGust': 7.48,
#   'windBearing': 225,
#   'cloudCover': 0.93,
#   'uvIndex': 2,
#   'visibility': 7.542,
#   'ozone': 301.4},
#  'hourly': {'summary': 'Mostly cloudy throughout the day.',
#   'icon': 'rain',
#   'data': [{'time': 1572508800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0108,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 42.33,
#     'apparentTemperature': 38.72,
#     'dewPoint': 29.44,
#     'humidity': 0.6,
#     'pressure': 1016.2,
#     'windSpeed': 5.71,
#     'windGust': 7.69,
#     'windBearing': 225,
#     'cloudCover': 0.94,
#     'uvIndex': 2,
#     'visibility': 7.266,
#     'ozone': 302},
#    {'time': 1572512400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0094,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 42.59,
#     'apparentTemperature': 38.98,
#     'dewPoint': 29.77,
#     'humidity': 0.6,
#     'pressure': 1016,
#     'windSpeed': 5.78,
#     'windGust': 7.21,
#     'windBearing': 224,
#     'cloudCover': 0.93,
#     'uvIndex': 2,
#     'visibility': 8.041,
#     'ozone': 300.6},
#    {'time': 1572516000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0067,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 42.26,
#     'apparentTemperature': 38.87,
#     'dewPoint': 30.92,
#     'humidity': 0.64,
#     'pressure': 1016.3,
#     'windSpeed': 5.37,
#     'windGust': 6.61,
#     'windBearing': 220,
#     'cloudCover': 0.96,
#     'uvIndex': 1,
#     'visibility': 9.512,
#     'ozone': 299.1},
#    {'time': 1572519600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0082,
#     'precipProbability': 0.09,
#     'precipType': 'rain',
#     'temperature': 40.65,
#     'apparentTemperature': 37.35,
#     'dewPoint': 32.22,
#     'humidity': 0.72,
#     'pressure': 1016.7,
#     'windSpeed': 4.84,
#     'windGust': 5.98,
#     'windBearing': 210,
#     'cloudCover': 0.92,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 297.5},
#    {'time': 1572523200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0042,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 38.85,
#     'apparentTemperature': 36.11,
#     'dewPoint': 33.15,
#     'humidity': 0.8,
#     'pressure': 1017,
#     'windSpeed': 3.88,
#     'windGust': 5.66,
#     'windBearing': 194,
#     'cloudCover': 0.89,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 296.3},
#    {'time': 1572526800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 37.87,
#     'apparentTemperature': 34.71,
#     'dewPoint': 32.62,
#     'humidity': 0.81,
#     'pressure': 1017.5,
#     'windSpeed': 4.15,
#     'windGust': 5.97,
#     'windBearing': 179,
#     'cloudCover': 0.93,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 295.5},
#    {'time': 1572530400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0006,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 36.89,
#     'apparentTemperature': 33.13,
#     'dewPoint': 31.86,
#     'humidity': 0.82,
#     'pressure': 1018,
#     'windSpeed': 4.63,
#     'windGust': 6.6,
#     'windBearing': 181,
#     'cloudCover': 0.93,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 295.1},
#    {'time': 1572534000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0019,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 36.18,
#     'apparentTemperature': 32.23,
#     'dewPoint': 30.73,
#     'humidity': 0.8,
#     'pressure': 1018.4,
#     'windSpeed': 4.72,
#     'windGust': 7.01,
#     'windBearing': 179,
#     'cloudCover': 0.97,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 294.8},
#    {'time': 1572537600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0082,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 35.87,
#     'apparentTemperature': 31.84,
#     'dewPoint': 29.37,
#     'humidity': 0.77,
#     'pressure': 1018.6,
#     'windSpeed': 4.76,
#     'windGust': 7.04,
#     'windBearing': 193,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 294.8},
#    {'time': 1572541200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0076,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 36.01,
#     'apparentTemperature': 31.78,
#     'dewPoint': 27.97,
#     'humidity': 0.72,
#     'pressure': 1018.4,
#     'windSpeed': 5.01,
#     'windGust': 6.93,
#     'windBearing': 187,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 294.8},
#    {'time': 1572544800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0072,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 35.88,
#     'apparentTemperature': 31.82,
#     'dewPoint': 27.14,
#     'humidity': 0.7,
#     'pressure': 1018.3,
#     'windSpeed': 4.77,
#     'windGust': 6.68,
#     'windBearing': 196,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 294.6},
#    {'time': 1572548400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0075,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 35.7,
#     'apparentTemperature': 31.54,
#     'dewPoint': 26.76,
#     'humidity': 0.7,
#     'pressure': 1018.2,
#     'windSpeed': 4.87,
#     'windGust': 6.67,
#     'windBearing': 195,
#     'cloudCover': 0.97,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 294},
#    {'time': 1572552000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0042,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 35.39,
#     'apparentTemperature': 31.23,
#     'dewPoint': 26.49,
#     'humidity': 0.7,
#     'pressure': 1018.1,
#     'windSpeed': 4.8,
#     'windGust': 6.56,
#     'windBearing': 201,
#     'cloudCover': 0.89,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 293.1},
#    {'time': 1572555600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0012,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 35.31,
#     'apparentTemperature': 31.35,
#     'dewPoint': 26.25,
#     'humidity': 0.69,
#     'pressure': 1018.3,
#     'windSpeed': 4.57,
#     'windGust': 6.36,
#     'windBearing': 197,
#     'cloudCover': 0.88,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 292.2},
#    {'time': 1572559200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 35.29,
#     'apparentTemperature': 31.61,
#     'dewPoint': 25.81,
#     'humidity': 0.68,
#     'pressure': 1018.1,
#     'windSpeed': 4.27,
#     'windGust': 5.89,
#     'windBearing': 196,
#     'cloudCover': 0.87,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 291.5},
#    {'time': 1572562800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 35.3,
#     'apparentTemperature': 31.64,
#     'dewPoint': 25.3,
#     'humidity': 0.67,
#     'pressure': 1017.9,
#     'windSpeed': 4.24,
#     'windGust': 5.35,
#     'windBearing': 195,
#     'cloudCover': 0.84,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 290.8},
#    {'time': 1572566400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 35.08,
#     'apparentTemperature': 31.53,
#     'dewPoint': 25.1,
#     'humidity': 0.67,
#     'pressure': 1018.3,
#     'windSpeed': 4.1,
#     'windGust': 4.96,
#     'windBearing': 190,
#     'cloudCover': 0.83,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 290.3},
#    {'time': 1572570000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-night',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperature': 34.91,
#     'apparentTemperature': 31.61,
#     'dewPoint': 25.3,
#     'humidity': 0.68,
#     'pressure': 1018.8,
#     'windSpeed': 3.84,
#     'windGust': 4.68,
#     'windBearing': 182,
#     'cloudCover': 0.84,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 290},
#    {'time': 1572573600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 34.19,
#     'apparentTemperature': 31.02,
#     'dewPoint': 26.08,
#     'humidity': 0.72,
#     'pressure': 1019.2,
#     'windSpeed': 3.63,
#     'windGust': 4.56,
#     'windBearing': 199,
#     'cloudCover': 0.8,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 289.8},
#    {'time': 1572577200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 34.75,
#     'apparentTemperature': 31.54,
#     'dewPoint': 26.9,
#     'humidity': 0.73,
#     'pressure': 1019.4,
#     'windSpeed': 3.73,
#     'windGust': 4.73,
#     'windBearing': 196,
#     'cloudCover': 0.8,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 289.5},
#    {'time': 1572580800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 36.92,
#     'apparentTemperature': 34.19,
#     'dewPoint': 28.02,
#     'humidity': 0.7,
#     'pressure': 1019.2,
#     'windSpeed': 3.59,
#     'windGust': 5.15,
#     'windBearing': 184,
#     'cloudCover': 0.73,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 288.8},
#    {'time': 1572584400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 39.81,
#     'apparentTemperature': 37.38,
#     'dewPoint': 29.27,
#     'humidity': 0.66,
#     'pressure': 1018.8,
#     'windSpeed': 3.71,
#     'windGust': 5.82,
#     'windBearing': 175,
#     'cloudCover': 0.63,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 287.8},
#    {'time': 1572588000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperature': 42.32,
#     'apparentTemperature': 39.92,
#     'dewPoint': 30.55,
#     'humidity': 0.63,
#     'pressure': 1018.5,
#     'windSpeed': 4.08,
#     'windGust': 6.25,
#     'windBearing': 301,
#     'cloudCover': 0.58,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 287},
#    {'time': 1572591600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 43.98,
#     'apparentTemperature': 41.73,
#     'dewPoint': 31.08,
#     'humidity': 0.6,
#     'pressure': 1017.9,
#     'windSpeed': 4.23,
#     'windGust': 6.13,
#     'windBearing': 317,
#     'cloudCover': 0.71,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 286.4},
#    {'time': 1572595200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0004,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 44.04,
#     'apparentTemperature': 41.87,
#     'dewPoint': 31.84,
#     'humidity': 0.62,
#     'pressure': 1017.2,
#     'windSpeed': 4.14,
#     'windGust': 5.88,
#     'windBearing': 350,
#     'cloudCover': 0.78,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 285.9},
#    {'time': 1572598800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 42.69,
#     'apparentTemperature': 40.6,
#     'dewPoint': 33.01,
#     'humidity': 0.68,
#     'pressure': 1016.8,
#     'windSpeed': 3.81,
#     'windGust': 5.52,
#     'windBearing': 16,
#     'cloudCover': 0.79,
#     'uvIndex': 2,
#     'visibility': 9.292,
#     'ozone': 285.7},
#    {'time': 1572602400,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0007,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 40.95,
#     'apparentTemperature': 38.87,
#     'dewPoint': 34.38,
#     'humidity': 0.77,
#     'pressure': 1016.9,
#     'windSpeed': 3.53,
#     'windGust': 5.24,
#     'windBearing': 41,
#     'cloudCover': 0.8,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 286},
#    {'time': 1572606000,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0017,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 38.72,
#     'apparentTemperature': 36.56,
#     'dewPoint': 35.78,
#     'humidity': 0.89,
#     'pressure': 1017.4,
#     'windSpeed': 3.3,
#     'windGust': 5.06,
#     'windBearing': 74,
#     'cloudCover': 0.86,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 286.7},
#    {'time': 1572609600,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0047,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 36.84,
#     'apparentTemperature': 34.45,
#     'dewPoint': 36.62,
#     'humidity': 0.99,
#     'pressure': 1017.8,
#     'windSpeed': 3.28,
#     'windGust': 5.02,
#     'windBearing': 91,
#     'cloudCover': 0.87,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.2},
#    {'time': 1572613200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.003,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperature': 36.35,
#     'apparentTemperature': 33.92,
#     'dewPoint': 36.03,
#     'humidity': 0.99,
#     'pressure': 1018.5,
#     'windSpeed': 3.25,
#     'windGust': 5.2,
#     'windBearing': 101,
#     'cloudCover': 0.88,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.2},
#    {'time': 1572616800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0016,
#     'precipProbability': 0.08,
#     'precipType': 'rain',
#     'temperature': 36.09,
#     'apparentTemperature': 33.67,
#     'dewPoint': 35.17,
#     'humidity': 0.96,
#     'pressure': 1019.2,
#     'windSpeed': 3.22,
#     'windGust': 5.49,
#     'windBearing': 123,
#     'cloudCover': 0.93,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 287.2},
#    {'time': 1572620400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.002,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 35.65,
#     'apparentTemperature': 33.1,
#     'dewPoint': 34.25,
#     'humidity': 0.95,
#     'pressure': 1019.6,
#     'windSpeed': 3.27,
#     'windGust': 5.63,
#     'windBearing': 141,
#     'cloudCover': 0.94,
#     'uvIndex': 0,
#     'visibility': 8.96,
#     'ozone': 287.1},
#    {'time': 1572624000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0009,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 35.46,
#     'apparentTemperature': 32.68,
#     'dewPoint': 33.44,
#     'humidity': 0.92,
#     'pressure': 1019.6,
#     'windSpeed': 3.45,
#     'windGust': 5.41,
#     'windBearing': 149,
#     'cloudCover': 0.95,
#     'uvIndex': 0,
#     'visibility': 7.844,
#     'ozone': 287.1},
#    {'time': 1572627600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0025,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 35.36,
#     'apparentTemperature': 32.53,
#     'dewPoint': 32.69,
#     'humidity': 0.9,
#     'pressure': 1019.6,
#     'windSpeed': 3.48,
#     'windGust': 5.05,
#     'windBearing': 159,
#     'cloudCover': 0.95,
#     'uvIndex': 0,
#     'visibility': 7.072,
#     'ozone': 287.1},
#    {'time': 1572631200,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0018,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 35.13,
#     'apparentTemperature': 32.08,
#     'dewPoint': 32.06,
#     'humidity': 0.88,
#     'pressure': 1019.8,
#     'windSpeed': 3.64,
#     'windGust': 4.81,
#     'windBearing': 162,
#     'cloudCover': 0.96,
#     'uvIndex': 0,
#     'visibility': 6.156,
#     'ozone': 287.2},
#    {'time': 1572634800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0011,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperature': 34.91,
#     'apparentTemperature': 32.03,
#     'dewPoint': 31.67,
#     'humidity': 0.88,
#     'pressure': 1019.9,
#     'windSpeed': 3.47,
#     'windGust': 4.92,
#     'windBearing': 166,
#     'cloudCover': 0.98,
#     'uvIndex': 0,
#     'visibility': 4.795,
#     'ozone': 287.5},
#    {'time': 1572638400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 34.86,
#     'apparentTemperature': 32.13,
#     'dewPoint': 31.43,
#     'humidity': 0.87,
#     'pressure': 1020.1,
#     'windSpeed': 3.33,
#     'windGust': 5.16,
#     'windBearing': 168,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 3.295,
#     'ozone': 287.9},
#    {'time': 1572642000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0019,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 34.85,
#     'apparentTemperature': 32.28,
#     'dewPoint': 31.28,
#     'humidity': 0.87,
#     'pressure': 1020.2,
#     'windSpeed': 3.2,
#     'windGust': 5.28,
#     'windBearing': 158,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 2.048,
#     'ozone': 288.2},
#    {'time': 1572645600,
#     'summary': 'Foggy',
#     'icon': 'fog',
#     'precipIntensity': 0.0022,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 34.95,
#     'apparentTemperature': 34.95,
#     'dewPoint': 31.2,
#     'humidity': 0.86,
#     'pressure': 1020.4,
#     'windSpeed': 2.93,
#     'windGust': 5.18,
#     'windBearing': 154,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 1.173,
#     'ozone': 288.2},
#    {'time': 1572649200,
#     'summary': 'Foggy',
#     'icon': 'fog',
#     'precipIntensity': 0.0024,
#     'precipProbability': 0.06,
#     'precipType': 'rain',
#     'temperature': 34.86,
#     'apparentTemperature': 34.86,
#     'dewPoint': 31.2,
#     'humidity': 0.86,
#     'pressure': 1020.6,
#     'windSpeed': 2.78,
#     'windGust': 4.97,
#     'windBearing': 150,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 0.555,
#     'ozone': 288.2},
#    {'time': 1572652800,
#     'summary': 'Foggy',
#     'icon': 'fog',
#     'precipIntensity': 0.0032,
#     'precipProbability': 0.07,
#     'precipType': 'rain',
#     'temperature': 34.5,
#     'apparentTemperature': 34.5,
#     'dewPoint': 31.39,
#     'humidity': 0.88,
#     'pressure': 1020.8,
#     'windSpeed': 2.45,
#     'windGust': 4.58,
#     'windBearing': 156,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 0.259,
#     'ozone': 288.6},
#    {'time': 1572656400,
#     'summary': 'Foggy',
#     'icon': 'fog',
#     'precipIntensity': 0.0067,
#     'precipProbability': 0.12,
#     'precipType': 'rain',
#     'temperature': 34.04,
#     'apparentTemperature': 34.04,
#     'dewPoint': 31.93,
#     'humidity': 0.92,
#     'pressure': 1021.2,
#     'windSpeed': 2.28,
#     'windGust': 3.83,
#     'windBearing': 158,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 0.406,
#     'ozone': 289.8},
#    {'time': 1572660000,
#     'summary': 'Foggy',
#     'icon': 'fog',
#     'precipIntensity': 0.0118,
#     'precipProbability': 0.18,
#     'precipType': 'rain',
#     'temperature': 33.15,
#     'apparentTemperature': 33.15,
#     'dewPoint': 32.88,
#     'humidity': 0.99,
#     'pressure': 1021.6,
#     'windSpeed': 2.03,
#     'windGust': 2.91,
#     'windBearing': 154,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 0.878,
#     'ozone': 291.4},
#    {'time': 1572663600,
#     'summary': 'Foggy',
#     'icon': 'fog',
#     'precipIntensity': 0.0144,
#     'precipProbability': 0.21,
#     'precipType': 'rain',
#     'temperature': 33.38,
#     'apparentTemperature': 33.38,
#     'dewPoint': 33.38,
#     'humidity': 1,
#     'pressure': 1022.1,
#     'windSpeed': 1.94,
#     'windGust': 2.4,
#     'windBearing': 148,
#     'cloudCover': 1,
#     'uvIndex': 0,
#     'visibility': 1.381,
#     'ozone': 292.6},
#    {'time': 1572667200,
#     'summary': 'Foggy',
#     'icon': 'fog',
#     'precipIntensity': 0.0126,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'temperature': 34.36,
#     'apparentTemperature': 34.36,
#     'dewPoint': 34.36,
#     'humidity': 1,
#     'pressure': 1022.2,
#     'windSpeed': 2.02,
#     'windGust': 2.71,
#     'windBearing': 124,
#     'cloudCover': 1,
#     'uvIndex': 1,
#     'visibility': 1.911,
#     'ozone': 293.2},
#    {'time': 1572670800,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0097,
#     'precipProbability': 0.18,
#     'precipType': 'rain',
#     'temperature': 35.33,
#     'apparentTemperature': 35.33,
#     'dewPoint': 35.33,
#     'humidity': 1,
#     'pressure': 1022.3,
#     'windSpeed': 2.38,
#     'windGust': 3.35,
#     'windBearing': 102,
#     'cloudCover': 1,
#     'uvIndex': 2,
#     'visibility': 2.477,
#     'ozone': 293.6},
#    {'time': 1572674400,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0093,
#     'precipProbability': 0.18,
#     'precipType': 'rain',
#     'temperature': 36.37,
#     'apparentTemperature': 36.37,
#     'dewPoint': 36.37,
#     'humidity': 1,
#     'pressure': 1022.2,
#     'windSpeed': 2.63,
#     'windGust': 3.77,
#     'windBearing': 69,
#     'cloudCover': 0.99,
#     'uvIndex': 2,
#     'visibility': 2.791,
#     'ozone': 293.7},
#    {'time': 1572678000,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0115,
#     'precipProbability': 0.2,
#     'precipType': 'rain',
#     'temperature': 37.14,
#     'apparentTemperature': 37.14,
#     'dewPoint': 37.14,
#     'humidity': 1,
#     'pressure': 1021.7,
#     'windSpeed': 2.88,
#     'windGust': 3.72,
#     'windBearing': 49,
#     'cloudCover': 1,
#     'uvIndex': 2,
#     'visibility': 2.657,
#     'ozone': 293.3},
#    {'time': 1572681600,
#     'summary': 'Overcast',
#     'icon': 'cloudy',
#     'precipIntensity': 0.0167,
#     'precipProbability': 0.24,
#     'precipType': 'rain',
#     'temperature': 36.73,
#     'apparentTemperature': 36.73,
#     'dewPoint': 36.73,
#     'humidity': 1,
#     'pressure': 1021.1,
#     'windSpeed': 2.99,
#     'windGust': 3.57,
#     'windBearing': 15,
#     'cloudCover': 1,
#     'uvIndex': 2,
#     'visibility': 2.276,
#     'ozone': 292.7}]},
#  'daily': {'summary': 'Mixed precipitation throughout the week.',
#   'icon': 'sleet',
#   'data': [{'time': 1572458400,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'rain',
#     'sunriseTime': 1572486480,
#     'sunsetTime': 1572523980,
#     'moonPhase': 0.13,
#     'precipIntensity': 0.0043,
#     'precipIntensityMax': 0.0108,
#     'precipIntensityMaxTime': 1572508740,
#     'precipProbability': 0.66,
#     'precipType': 'rain',
#     'temperatureHigh': 43.09,
#     'temperatureHighTime': 1572512160,
#     'temperatureLow': 33.7,
#     'temperatureLowTime': 1572573600,
#     'apparentTemperatureHigh': 39.04,
#     'apparentTemperatureHighTime': 1572514320,
#     'apparentTemperatureLow': 31.02,
#     'apparentTemperatureLowTime': 1572573600,
#     'dewPoint': 29.48,
#     'humidity': 0.72,
#     'pressure': 1017.1,
#     'windSpeed': 5.51,
#     'windGust': 10.97,
#     'windGustTime': 1572462660,
#     'windBearing': 193,
#     'cloudCover': 0.85,
#     'uvIndex': 3,
#     'uvIndexTime': 1572504900,
#     'visibility': 8.954,
#     'ozone': 302.6,
#     'temperatureMin': 35,
#     'temperatureMinTime': 1572489540,
#     'temperatureMax': 43.09,
#     'temperatureMaxTime': 1572512160,
#     'apparentTemperatureMin': 30.85,
#     'apparentTemperatureMinTime': 1572487620,
#     'apparentTemperatureMax': 39.04,
#     'apparentTemperatureMaxTime': 1572514320},
#    {'time': 1572544800,
#     'summary': 'Foggy overnight.',
#     'icon': 'rain',
#     'sunriseTime': 1572573000,
#     'sunsetTime': 1572610260,
#     'moonPhase': 0.16,
#     'precipIntensity': 0.0016,
#     'precipIntensityMax': 0.0077,
#     'precipIntensityMaxTime': 1572547560,
#     'precipProbability': 0.57,
#     'precipType': 'rain',
#     'temperatureHigh': 44.7,
#     'temperatureHighTime': 1572593520,
#     'temperatureLow': 32.66,
#     'temperatureLowTime': 1572660000,
#     'apparentTemperatureHigh': 42,
#     'apparentTemperatureHighTime': 1572593700,
#     'apparentTemperatureLow': 32.02,
#     'apparentTemperatureLowTime': 1572633360,
#     'dewPoint': 30.24,
#     'humidity': 0.76,
#     'pressure': 1018.4,
#     'windSpeed': 3.86,
#     'windGust': 6.68,
#     'windGustTime': 1572544800,
#     'windBearing': 181,
#     'cloudCover': 0.84,
#     'uvIndex': 3,
#     'uvIndexTime': 1572590820,
#     'visibility': 9.669,
#     'ozone': 288.7,
#     'temperatureMin': 33.7,
#     'temperatureMinTime': 1572573900,
#     'temperatureMax': 44.7,
#     'temperatureMaxTime': 1572593520,
#     'apparentTemperatureMin': 31.02,
#     'apparentTemperatureMinTime': 1572574080,
#     'apparentTemperatureMax': 42,
#     'apparentTemperatureMaxTime': 1572593700},
#    {'time': 1572631200,
#     'summary': 'Possible light rain until evening.',
#     'icon': 'rain',
#     'sunriseTime': 1572659460,
#     'sunsetTime': 1572696600,
#     'moonPhase': 0.19,
#     'precipIntensity': 0.008,
#     'precipIntensityMax': 0.0171,
#     'precipIntensityMaxTime': 1572683100,
#     'precipProbability': 0.85,
#     'precipType': 'rain',
#     'temperatureHigh': 37.65,
#     'temperatureHighTime': 1572678300,
#     'temperatureLow': 31.8,
#     'temperatureLowTime': 1572745380,
#     'apparentTemperatureHigh': 37.15,
#     'apparentTemperatureHighTime': 1572678300,
#     'apparentTemperatureLow': 28.41,
#     'apparentTemperatureLowTime': 1572744960,
#     'dewPoint': 33.33,
#     'humidity': 0.94,
#     'pressure': 1021.3,
#     'windSpeed': 2.89,
#     'windGust': 6.16,
#     'windGustTime': 1572717600,
#     'windBearing': 139,
#     'cloudCover': 0.98,
#     'uvIndex': 2,
#     'uvIndexTime': 1572677940,
#     'visibility': 3.608,
#     'ozone': 291.9,
#     'temperatureMin': 32.62,
#     'temperatureMinTime': 1572660900,
#     'temperatureMax': 37.65,
#     'temperatureMaxTime': 1572678300,
#     'apparentTemperatureMin': 29.86,
#     'apparentTemperatureMinTime': 1572717600,
#     'apparentTemperatureMax': 37.15,
#     'apparentTemperatureMaxTime': 1572678300},
#    {'time': 1572717600,
#     'summary': 'Overcast throughout the day.',
#     'icon': 'cloudy',
#     'sunriseTime': 1572745920,
#     'sunsetTime': 1572782940,
#     'moonPhase': 0.23,
#     'precipIntensity': 0.0013,
#     'precipIntensityMax': 0.0078,
#     'precipIntensityMaxTime': 1572761280,
#     'precipProbability': 0.35,
#     'precipType': 'rain',
#     'temperatureHigh': 45.04,
#     'temperatureHighTime': 1572768000,
#     'temperatureLow': 33.48,
#     'temperatureLowTime': 1572832740,
#     'apparentTemperatureHigh': 43.29,
#     'apparentTemperatureHighTime': 1572767820,
#     'apparentTemperatureLow': 29.01,
#     'apparentTemperatureLowTime': 1572832800,
#     'dewPoint': 26.71,
#     'humidity': 0.68,
#     'pressure': 1019,
#     'windSpeed': 4.11,
#     'windGust': 8.07,
#     'windGustTime': 1572793740,
#     'windBearing': 187,
#     'cloudCover': 0.92,
#     'uvIndex': 2,
#     'uvIndexTime': 1572764400,
#     'visibility': 9.952,
#     'ozone': 299.1,
#     'temperatureMin': 31.8,
#     'temperatureMinTime': 1572745380,
#     'temperatureMax': 45.04,
#     'temperatureMaxTime': 1572768000,
#     'apparentTemperatureMin': 28.41,
#     'apparentTemperatureMinTime': 1572744960,
#     'apparentTemperatureMax': 43.29,
#     'apparentTemperatureMaxTime': 1572767820},
#    {'time': 1572804000,
#     'summary': 'Possible light rain throughout the day.',
#     'icon': 'rain',
#     'sunriseTime': 1572832380,
#     'sunsetTime': 1572869280,
#     'moonPhase': 0.26,
#     'precipIntensity': 0.0116,
#     'precipIntensityMax': 0.0205,
#     'precipIntensityMaxTime': 1572848700,
#     'precipProbability': 0.79,
#     'precipType': 'rain',
#     'temperatureHigh': 40.18,
#     'temperatureHighTime': 1572848460,
#     'temperatureLow': 17.95,
#     'temperatureLowTime': 1572918840,
#     'apparentTemperatureHigh': 35.88,
#     'apparentTemperatureHighTime': 1572848520,
#     'apparentTemperatureLow': 12.62,
#     'apparentTemperatureLowTime': 1572916260,
#     'dewPoint': 23.71,
#     'humidity': 0.69,
#     'pressure': 1021.1,
#     'windSpeed': 5.66,
#     'windGust': 11.49,
#     'windGustTime': 1572868560,
#     'windBearing': 200,
#     'cloudCover': 0.99,
#     'uvIndex': 2,
#     'uvIndexTime': 1572850740,
#     'visibility': 6.066,
#     'ozone': 309.4,
#     'temperatureMin': 22.83,
#     'temperatureMinTime': 1572890400,
#     'temperatureMax': 40.18,
#     'temperatureMaxTime': 1572848460,
#     'apparentTemperatureMin': 18.34,
#     'apparentTemperatureMinTime': 1572890400,
#     'apparentTemperatureMax': 35.88,
#     'apparentTemperatureMaxTime': 1572848520},
#    {'time': 1572890400,
#     'summary': 'Possible flurries until evening.',
#     'icon': 'snow',
#     'sunriseTime': 1572918900,
#     'sunsetTime': 1572955560,
#     'moonPhase': 0.29,
#     'precipIntensity': 0.0073,
#     'precipIntensityMax': 0.0177,
#     'precipIntensityMaxTime': 1572894120,
#     'precipProbability': 0.84,
#     'precipType': 'snow',
#     'precipAccumulation': 2.44,
#     'temperatureHigh': 28.42,
#     'temperatureHighTime': 1572940800,
#     'temperatureLow': 16.13,
#     'temperatureLowTime': 1573005060,
#     'apparentTemperatureHigh': 23.48,
#     'apparentTemperatureHighTime': 1572940800,
#     'apparentTemperatureLow': 13.6,
#     'apparentTemperatureLowTime': 1572975840,
#     'dewPoint': 12.6,
#     'humidity': 0.68,
#     'pressure': 1028.1,
#     'windSpeed': 3.53,
#     'windGust': 5.39,
#     'windGustTime': 1572911640,
#     'windBearing': 180,
#     'cloudCover': 0.92,
#     'uvIndex': 2,
#     'uvIndexTime': 1572936900,
#     'visibility': 3.065,
#     'ozone': 312.5,
#     'temperatureMin': 17.83,
#     'temperatureMinTime': 1572976800,
#     'temperatureMax': 28.42,
#     'temperatureMaxTime': 1572940800,
#     'apparentTemperatureMin': 12.62,
#     'apparentTemperatureMinTime': 1572916260,
#     'apparentTemperatureMax': 23.48,
#     'apparentTemperatureMaxTime': 1572940800},
#    {'time': 1572976800,
#     'summary': 'Possible light snow until evening.',
#     'icon': 'snow',
#     'sunriseTime': 1573005360,
#     'sunsetTime': 1573041900,
#     'moonPhase': 0.32,
#     'precipIntensity': 0.0057,
#     'precipIntensityMax': 0.0168,
#     'precipIntensityMaxTime': 1572999660,
#     'precipProbability': 0.85,
#     'precipType': 'snow',
#     'precipAccumulation': 2.24,
#     'temperatureHigh': 26.22,
#     'temperatureHighTime': 1573026060,
#     'temperatureLow': 14.9,
#     'temperatureLowTime': 1573091340,
#     'apparentTemperatureHigh': 21.95,
#     'apparentTemperatureHighTime': 1573026000,
#     'apparentTemperatureLow': 9.32,
#     'apparentTemperatureLowTime': 1573068660,
#     'dewPoint': 11.09,
#     'humidity': 0.71,
#     'pressure': 1029.3,
#     'windSpeed': 2.9,
#     'windGust': 5.78,
#     'windGustTime': 1573028340,
#     'windBearing': 181,
#     'cloudCover': 0.92,
#     'uvIndex': 2,
#     'uvIndexTime': 1573023720,
#     'visibility': 2.717,
#     'ozone': 308.7,
#     'temperatureMin': 15.75,
#     'temperatureMinTime': 1573063200,
#     'temperatureMax': 26.22,
#     'temperatureMaxTime': 1573026060,
#     'apparentTemperatureMin': 9.88,
#     'apparentTemperatureMinTime': 1573063200,
#     'apparentTemperatureMax': 21.95,
#     'apparentTemperatureMaxTime': 1573026000},
#    {'time': 1573063200,
#     'summary': 'Possible flurries in the afternoon and evening.',
#     'icon': 'snow',
#     'sunriseTime': 1573091820,
#     'sunsetTime': 1573128240,
#     'moonPhase': 0.35,
#     'precipIntensity': 0.0043,
#     'precipIntensityMax': 0.0128,
#     'precipIntensityMaxTime': 1573126860,
#     'precipProbability': 0.62,
#     'precipType': 'snow',
#     'precipAccumulation': 1.44,
#     'temperatureHigh': 27.95,
#     'temperatureHighTime': 1573113060,
#     'temperatureLow': 18.45,
#     'temperatureLowTime': 1573177020,
#     'apparentTemperatureHigh': 22.56,
#     'apparentTemperatureHighTime': 1573112940,
#     'apparentTemperatureLow': 12.28,
#     'apparentTemperatureLowTime': 1573176060,
#     'dewPoint': 12.41,
#     'humidity': 0.73,
#     'pressure': 1030.1,
#     'windSpeed': 3.74,
#     'windGust': 11.56,
#     'windGustTime': 1573117080,
#     'windBearing': 187,
#     'cloudCover': 0.61,
#     'uvIndex': 2,
#     'uvIndexTime': 1573109640,
#     'visibility': 6.019,
#     'ozone': 319.1,
#     'temperatureMin': 14.9,
#     'temperatureMinTime': 1573091340,
#     'temperatureMax': 27.95,
#     'temperatureMaxTime': 1573113060,
#     'apparentTemperatureMin': 9.32,
#     'apparentTemperatureMinTime': 1573068660,
#     'apparentTemperatureMax': 22.56,
#     'apparentTemperatureMaxTime': 1573112940}]},
#  'flags': {'sources': ['cmc', 'gfs', 'icon', 'isd', 'madis'],
#   'nearest-station': 12.977,
#   'units': 'us'},
#  'offset': 6}

# %%
f = forecast.json()

# %%
print(type(f))
# Out:
# <class 'dict'>

# %%
f.keys()
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'hourly', 'daily', 'flags', 'offset'])

# %%
pd.DataFrame.from_dict(f)
# Out:
#                      latitude  longitude     timezone   currently  \
# time                  42.3601    71.0589  Asia/Almaty  1572510394
# summary               42.3601    71.0589  Asia/Almaty    Overcast
# icon                  42.3601    71.0589  Asia/Almaty      cloudy
# precipIntensity       42.3601    71.0589  Asia/Almaty      0.0105
# precipProbability     42.3601    71.0589  Asia/Almaty        0.07
# precipType            42.3601    71.0589  Asia/Almaty        rain
# temperature           42.3601    71.0589  Asia/Almaty       42.52
# apparentTemperature   42.3601    71.0589  Asia/Almaty       38.92
# dewPoint              42.3601    71.0589  Asia/Almaty       29.51
# humidity              42.3601    71.0589  Asia/Almaty         0.6
# pressure              42.3601    71.0589  Asia/Almaty      1016.1
# windSpeed             42.3601    71.0589  Asia/Almaty        5.76
# windGust              42.3601    71.0589  Asia/Almaty        7.48
# windBearing           42.3601    71.0589  Asia/Almaty         225
# cloudCover            42.3601    71.0589  Asia/Almaty        0.93
# uvIndex               42.3601    71.0589  Asia/Almaty           2
# visibility            42.3601    71.0589  Asia/Almaty       7.542
# ozone                 42.3601    71.0589  Asia/Almaty       301.4
# data                  42.3601    71.0589  Asia/Almaty         NaN
# sources               42.3601    71.0589  Asia/Almaty         NaN
# nearest-station       42.3601    71.0589  Asia/Almaty         NaN
# units                 42.3601    71.0589  Asia/Almaty         NaN
#
#                                                                 hourly  \
# time                                                               NaN
# summary                              Mostly cloudy throughout the day.
# icon                                                              rain
# precipIntensity                                                    NaN
# precipProbability                                                  NaN
# precipType                                                         NaN
# temperature                                                        NaN
# apparentTemperature                                                NaN
# dewPoint                                                           NaN
# humidity                                                           NaN
# pressure                                                           NaN
# windSpeed                                                          NaN
# windGust                                                           NaN
# windBearing                                                        NaN
# cloudCover                                                         NaN
# uvIndex                                                            NaN
# visibility                                                         NaN
# ozone                                                              NaN
# data                 [{'time': 1572508800, 'summary': 'Overcast', '...
# sources                                                            NaN
# nearest-station                                                    NaN
# units                                                              NaN
#
#                                                                  daily  \
# time                                                               NaN
# summary                       Mixed precipitation throughout the week.
# icon                                                             sleet
# precipIntensity                                                    NaN
# precipProbability                                                  NaN
# precipType                                                         NaN
# temperature                                                        NaN
# apparentTemperature                                                NaN
# dewPoint                                                           NaN
# humidity                                                           NaN
# pressure                                                           NaN
# windSpeed                                                          NaN
# windGust                                                           NaN
# windBearing                                                        NaN
# cloudCover                                                         NaN
# uvIndex                                                            NaN
# visibility                                                         NaN
# ozone                                                              NaN
# data                 [{'time': 1572458400, 'summary': 'Mostly cloud...
# sources                                                            NaN
# nearest-station                                                    NaN
# units                                                              NaN
#
#                                             flags  offset
# time                                          NaN       6
# summary                                       NaN       6
# icon                                          NaN       6
# precipIntensity                               NaN       6
# precipProbability                             NaN       6
# precipType                                    NaN       6
# temperature                                   NaN       6
# apparentTemperature                           NaN       6
# dewPoint                                      NaN       6
# humidity                                      NaN       6
# pressure                                      NaN       6
# windSpeed                                     NaN       6
# windGust                                      NaN       6
# windBearing                                   NaN       6
# cloudCover                                    NaN       6
# uvIndex                                       NaN       6
# visibility                                    NaN       6
# ozone                                         NaN       6
# data                                          NaN       6
# sources              [cmc, gfs, icon, isd, madis]       6
# nearest-station                            12.977       6
# units                                          us       6

# %%
location = (42.3601,71.0589)

# %%
WeatherGetter()

# %%
import sqlite3
conn = sqlite3.connect('database.sqlite')
cur = conn.cursor()
